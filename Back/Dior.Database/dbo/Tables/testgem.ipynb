-- %% [markdown]
-- # [dbo].[ACCESS]

-- %%
USE [Dior.Database]
GO

-- %%
/****** Object:  Table [dbo].[ACCESS]    Script Date: 20/08/2025 01:15:53 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ACCESS](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[badgePhysicalNumber] [nvarchar](100) NOT NULL,
	[isActive] [bit] NOT NULL,
	[createdAt] [datetime] NOT NULL,
	[createdBy] [nvarchar](100) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [UQ_access_badgePhysicalNumber] UNIQUE NONCLUSTERED 
(
	[badgePhysicalNumber] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ACCESS_COMPETENCY]

-- %%
/****** Object:  Table [dbo].[ACCESS_COMPETENCY]    Script Date: 20/08/2025 01:15:54 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ACCESS_COMPETENCY](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[name] [nvarchar](100) NOT NULL,
	[parentId] [int] NULL,
	[isActive] [bit] NOT NULL,
	[createdAt] [datetime] NOT NULL,
	[createdBy] [nvarchar](100) NULL,
	[lastEditAt] [datetime] NULL,
	[lastEditBy] [nvarchar](100) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [UQ_accessCompetency_name] UNIQUE NONCLUSTERED 
(
	[name] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[AUDIT_LOGS]

-- %%
/****** Object:  Table [dbo].[AUDIT_LOGS]    Script Date: 20/08/2025 01:15:54 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[AUDIT_LOGS](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[userId] [bigint] NOT NULL,
	[action] [nvarchar](100) NOT NULL,
	[tableName] [nvarchar](100) NOT NULL,
	[recordId] [int] NOT NULL,
	[details] [nvarchar](max) NULL,
	[timestamp] [datetime] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Contract]

-- %%
/****** Object:  Table [dbo].[Contract]    Script Date: 20/08/2025 01:15:54 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Contract](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[UserId] [bigint] NOT NULL,
	[FileName] [nvarchar](255) NOT NULL,
	[FileUrl] [nvarchar](1024) NOT NULL,
	[UploadDate] [datetime] NOT NULL,
	[Description] [nvarchar](max) NULL,
	[UploadedBy] [nvarchar](100) NULL,
	[LastEditAt] [datetime] NULL,
	[LastEditBy] [nvarchar](100) NULL,
	[ContractType] [nvarchar](50) NULL,
	[StartDate] [datetime] NULL,
	[EndDate] [datetime] NULL,
	[Salary] [decimal](18, 2) NULL,
	[Currency] [nvarchar](10) NULL,
	[PaymentFrequency] [nvarchar](50) NULL,
	[Status] [nvarchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Messages]

-- %%
/****** Object:  Table [dbo].[Messages]    Script Date: 20/08/2025 01:15:54 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Messages](
	[Id] [bigint] IDENTITY(1,1) NOT NULL,
	[SenderId] [bigint] NOT NULL,
	[RecipientUserId] [bigint] NULL,
	[RecipientTeamId] [int] NULL,
	[Subject] [nvarchar](200) NOT NULL,
	[Content] [nvarchar](max) NOT NULL,
	[Priority] [nvarchar](20) NULL,
	[MessageType] [nvarchar](50) NULL,
	[IsRead] [bit] NULL,
	[ReadAt] [datetime] NULL,
	[SentAt] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NOTIFICATIONS]

-- %%
/****** Object:  Table [dbo].[NOTIFICATIONS]    Script Date: 20/08/2025 01:15:54 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NOTIFICATIONS](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[UserId] [bigint] NOT NULL,
	[Type] [nvarchar](50) NOT NULL,
	[Message] [nvarchar](max) NULL,
	[IsRead] [bit] NOT NULL,
	[CreatedAt] [datetime] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PASSWORD_HISTORY]

-- %%
/****** Object:  Table [dbo].[PASSWORD_HISTORY]    Script Date: 20/08/2025 01:15:54 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PASSWORD_HISTORY](
	[Id] [bigint] IDENTITY(1,1) NOT NULL,
	[UserId] [bigint] NOT NULL,
	[PasswordHash] [nvarchar](200) NOT NULL,
	[CreatedAt] [datetime] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Payslips]

-- %%
/****** Object:  Table [dbo].[Payslips]    Script Date: 20/08/2025 01:15:54 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Payslips](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[UserId] [bigint] NOT NULL,
	[Month] [int] NOT NULL,
	[Year] [int] NOT NULL,
	[GrossSalary] [decimal](18, 2) NOT NULL,
	[NetSalary] [decimal](18, 2) NOT NULL,
	[Deductions] [decimal](18, 2) NULL,
	[Bonus] [decimal](18, 2) NULL,
	[FileUrl] [nvarchar](500) NULL,
	[IsSent] [bit] NULL,
	[SentDate] [datetime] NULL,
	[GeneratedAt] [datetime] NULL,
	[GeneratedBy] [nvarchar](100) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [UQ_Payslip_Period] UNIQUE NONCLUSTERED 
(
	[UserId] ASC,
	[Month] ASC,
	[Year] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PRIVILEGE]

-- %%
/****** Object:  Table [dbo].[PRIVILEGE]    Script Date: 20/08/2025 01:15:54 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PRIVILEGE](
	[ID] [bigint] IDENTITY(1,1) NOT NULL,
	[Name] [nvarchar](50) NOT NULL,
	[Description] [nvarchar](max) NULL,
	[IsConfigurableRead] [bit] NOT NULL,
	[IsConfigurableDelete] [bit] NOT NULL,
	[IsConfigurableAdd] [bit] NOT NULL,
	[IsConfigurableModify] [bit] NOT NULL,
	[IsConfigurableStatus] [bit] NOT NULL,
	[IsConfigurableExecution] [bit] NOT NULL,
	[LastEditBy] [nvarchar](50) NOT NULL,
	[LastEditAt] [datetime] NOT NULL,
 CONSTRAINT [PK_Privilege] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [UQ_Privilege_Name] UNIQUE NONCLUSTERED 
(
	[Name] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Projet]

-- %%
/****** Object:  Table [dbo].[Projet]    Script Date: 20/08/2025 01:15:54 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Projet](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Nom] [nvarchar](100) NOT NULL,
	[Description] [nvarchar](max) NULL,
	[DateDebut] [date] NULL,
	[DateFin] [date] NULL,
	[CreatedAt] [datetime] NOT NULL,
	[CreatedBy] [nvarchar](100) NULL,
	[LastEditAt] [datetime] NULL,
	[LastEditBy] [nvarchar](100) NULL,
	[TeamId] [int] NULL,
	[ManagerId] [bigint] NULL,
	[Type] [nvarchar](50) NULL,
	[Progress] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ROLE_DEFINITION]

-- %%
/****** Object:  Table [dbo].[ROLE_DEFINITION]    Script Date: 20/08/2025 01:15:54 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ROLE_DEFINITION](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[name] [nvarchar](100) NOT NULL,
	[description] [nvarchar](max) NULL,
	[parentRoleId] [int] NULL,
	[isActive] [bit] NOT NULL,
	[createdAt] [datetime] NOT NULL,
	[createdBy] [nvarchar](100) NULL,
	[lastEditAt] [datetime] NULL,
	[lastEditBy] [nvarchar](100) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [UQ_roleDefinition_name] UNIQUE NONCLUSTERED 
(
	[name] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[RoleDefinitionPrivilege]

-- %%
/****** Object:  Table [dbo].[RoleDefinitionPrivilege]    Script Date: 20/08/2025 01:15:54 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[RoleDefinitionPrivilege](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[roleDefinitionId] [int] NOT NULL,
	[PrivilegeId] [bigint] NOT NULL,
	[createdAt] [datetime] NOT NULL,
	[createdBy] [nvarchar](100) NULL,
	[lastEditAt] [datetime] NULL,
	[lastEditBy] [nvarchar](100) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Task]

-- %%
/****** Object:  Table [dbo].[Task]    Script Date: 20/08/2025 01:15:54 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Task](
	[Id] [bigint] IDENTITY(1,1) NOT NULL,
	[Title] [nvarchar](255) NOT NULL,
	[Description] [nvarchar](max) NULL,
	[Status] [nvarchar](50) NOT NULL,
	[AssignedToUserId] [bigint] NOT NULL,
	[CreatedByUserId] [bigint] NOT NULL,
	[CreatedAt] [datetime] NOT NULL,
	[DueDate] [datetime] NULL,
	[LastEditAt] [datetime] NULL,
	[LastEditBy] [nvarchar](100) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Team]

-- %%
/****** Object:  Table [dbo].[Team]    Script Date: 20/08/2025 01:15:54 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Team](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Name] [nvarchar](100) NOT NULL,
	[Description] [nvarchar](255) NULL,
	[CreatedAt] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[USER]

-- %%
/****** Object:  Table [dbo].[USER]    Script Date: 20/08/2025 01:15:54 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[USER](
	[ID] [bigint] IDENTITY(1,1) NOT NULL,
	[IsActive] [bit] NOT NULL,
	[Username] [nvarchar](50) NOT NULL,
	[LastName] [nvarchar](50) NOT NULL,
	[FirstName] [nvarchar](50) NOT NULL,
	[LastEditBy] [nvarchar](50) NOT NULL,
	[LastEditAt] [datetime] NOT NULL,
	[passwordHash] [nvarchar](200) NULL,
	[Email] [nvarchar](255) NULL,
	[Phone] [nvarchar](20) NULL,
	[TeamId] [int] NULL,
	[DeletedAt] [datetime] NULL,
	[DeletedBy] [nvarchar](100) NULL,
	[CreatedAt] [datetime] NOT NULL,
	[CreatedBy] [nvarchar](100) NULL,
 CONSTRAINT [PK_User] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [UQ_User_Name] UNIQUE NONCLUSTERED 
(
	[Username] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [UQ_User_Username] UNIQUE NONCLUSTERED 
(
	[Username] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[USER_ROLE]

-- %%
/****** Object:  Table [dbo].[USER_ROLE]    Script Date: 20/08/2025 01:15:54 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[USER_ROLE](
	[ID] [bigint] IDENTITY(1,1) NOT NULL,
	[RoleDefinitionID] [bigint] NOT NULL,
	[UserID] [bigint] NOT NULL,
	[LastEditBy] [nvarchar](50) NOT NULL,
	[LastEditAt] [datetime] NOT NULL,
 CONSTRAINT [PK_User_Role] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [UQ_User_Role_RoleDefinitiionID_UserID] UNIQUE NONCLUSTERED 
(
	[RoleDefinitionID] ASC,
	[UserID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[UserAccess]

-- %%
/****** Object:  Table [dbo].[UserAccess]    Script Date: 20/08/2025 01:15:54 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[UserAccess](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[UserId] [bigint] NOT NULL,
	[AccessId] [int] NOT NULL,
	[CreatedAt] [datetime] NOT NULL,
	[CreatedBy] [nvarchar](100) NULL,
	[LastEditAt] [datetime] NULL,
	[LastEditBy] [nvarchar](100) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[UserAccessCompetency]

-- %%
/****** Object:  Table [dbo].[UserAccessCompetency]    Script Date: 20/08/2025 01:15:54 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[UserAccessCompetency](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[UserId] [bigint] NOT NULL,
	[AccessCompetencyId] [int] NOT NULL,
	[CreatedAt] [datetime] NOT NULL,
	[CreatedBy] [nvarchar](100) NULL,
	[LastEditAt] [datetime] NULL,
	[LastEditBy] [nvarchar](100) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__ACCESS__isActive__3E52440B]

-- %%
ALTER TABLE [dbo].[ACCESS] ADD  DEFAULT ((1)) FOR [isActive]
GO

-- %% [markdown]
-- # [DF__ACCESS__createdA__3F466844]

-- %%
ALTER TABLE [dbo].[ACCESS] ADD  DEFAULT (getdate()) FOR [createdAt]
GO

-- %% [markdown]
-- # [DF__ACCESS_CO__isAct__4CA06362]

-- %%
ALTER TABLE [dbo].[ACCESS_COMPETENCY] ADD  DEFAULT ((1)) FOR [isActive]
GO

-- %% [markdown]
-- # [DF__ACCESS_CO__creat__4D94879B]

-- %%
ALTER TABLE [dbo].[ACCESS_COMPETENCY] ADD  DEFAULT (getdate()) FOR [createdAt]
GO

-- %% [markdown]
-- # [DF__AUDIT_LOG__times__6477ECF3]

-- %%
ALTER TABLE [dbo].[AUDIT_LOGS] ADD  DEFAULT (getdate()) FOR [timestamp]
GO

-- %% [markdown]
-- # [DF__Contract__Upload__16CE6296]

-- %%
ALTER TABLE [dbo].[Contract] ADD  DEFAULT (getdate()) FOR [UploadDate]
GO

-- %% [markdown]
-- # [DF__Contract__Contra__5D2BD0E6]

-- %%
ALTER TABLE [dbo].[Contract] ADD  DEFAULT ('CDI') FOR [ContractType]
GO

-- %% [markdown]
-- # [DF__Contract__Salary__5E1FF51F]

-- %%
ALTER TABLE [dbo].[Contract] ADD  DEFAULT ((0)) FOR [Salary]
GO

-- %% [markdown]
-- # [DF__Contract__Curren__5F141958]

-- %%
ALTER TABLE [dbo].[Contract] ADD  DEFAULT ('EUR') FOR [Currency]
GO

-- %% [markdown]
-- # [DF__Contract__Paymen__60083D91]

-- %%
ALTER TABLE [dbo].[Contract] ADD  DEFAULT ('Mensuel') FOR [PaymentFrequency]
GO

-- %% [markdown]
-- # [DF__Contract__Status__60FC61CA]

-- %%
ALTER TABLE [dbo].[Contract] ADD  DEFAULT ('Actif') FOR [Status]
GO

-- %% [markdown]
-- # [DF__Messages__Priori__473C8FC7]

-- %%
ALTER TABLE [dbo].[Messages] ADD  DEFAULT ('Normal') FOR [Priority]
GO

-- %% [markdown]
-- # [DF__Messages__Messag__4830B400]

-- %%
ALTER TABLE [dbo].[Messages] ADD  DEFAULT ('General') FOR [MessageType]
GO

-- %% [markdown]
-- # [DF__Messages__IsRead__4924D839]

-- %%
ALTER TABLE [dbo].[Messages] ADD  DEFAULT ((0)) FOR [IsRead]
GO

-- %% [markdown]
-- # [DF__Messages__SentAt__4A18FC72]

-- %%
ALTER TABLE [dbo].[Messages] ADD  DEFAULT (getdate()) FOR [SentAt]
GO

-- %% [markdown]
-- # [DF__NOTIFICAT__IsRea__2057CCD0]

-- %%
ALTER TABLE [dbo].[NOTIFICATIONS] ADD  DEFAULT ((0)) FOR [IsRead]
GO

-- %% [markdown]
-- # [DF__NOTIFICAT__Creat__214BF109]

-- %%
ALTER TABLE [dbo].[NOTIFICATIONS] ADD  DEFAULT (getdate()) FOR [CreatedAt]
GO

-- %% [markdown]
-- # [DF__PASSWORD___Creat__39E294A9]

-- %%
ALTER TABLE [dbo].[PASSWORD_HISTORY] ADD  DEFAULT (getdate()) FOR [CreatedAt]
GO

-- %% [markdown]
-- # [DF__Payslips__Deduct__54968AE5]

-- %%
ALTER TABLE [dbo].[Payslips] ADD  DEFAULT ((0)) FOR [Deductions]
GO

-- %% [markdown]
-- # [DF__Payslips__Bonus__567ED357]

-- %%
ALTER TABLE [dbo].[Payslips] ADD  DEFAULT ((0)) FOR [Bonus]
GO

-- %% [markdown]
-- # [DF__Payslips__FileUr__58671BC9]

-- %%
ALTER TABLE [dbo].[Payslips] ADD  DEFAULT ('') FOR [FileUrl]
GO

-- %% [markdown]
-- # [DF__Payslips__IsSent__595B4002]

-- %%
ALTER TABLE [dbo].[Payslips] ADD  DEFAULT ((0)) FOR [IsSent]
GO

-- %% [markdown]
-- # [DF__Payslips__Genera__5A4F643B]

-- %%
ALTER TABLE [dbo].[Payslips] ADD  DEFAULT (getdate()) FOR [GeneratedAt]
GO

-- %% [markdown]
-- # [DF__Payslips__Genera__5B438874]

-- %%
ALTER TABLE [dbo].[Payslips] ADD  DEFAULT ('System') FOR [GeneratedBy]
GO

-- %% [markdown]
-- # [DF_Privilege_IsConfigurableRead]

-- %%
ALTER TABLE [dbo].[PRIVILEGE] ADD  CONSTRAINT [DF_Privilege_IsConfigurableRead]  DEFAULT ((0)) FOR [IsConfigurableRead]
GO

-- %% [markdown]
-- # [DF_Privilege_IsConfigurableDelete]

-- %%
ALTER TABLE [dbo].[PRIVILEGE] ADD  CONSTRAINT [DF_Privilege_IsConfigurableDelete]  DEFAULT ((0)) FOR [IsConfigurableDelete]
GO

-- %% [markdown]
-- # [DF_Privilege_IsConfigurableAdd]

-- %%
ALTER TABLE [dbo].[PRIVILEGE] ADD  CONSTRAINT [DF_Privilege_IsConfigurableAdd]  DEFAULT ((0)) FOR [IsConfigurableAdd]
GO

-- %% [markdown]
-- # [DF_Privilege_IsConfigurableModify]

-- %%
ALTER TABLE [dbo].[PRIVILEGE] ADD  CONSTRAINT [DF_Privilege_IsConfigurableModify]  DEFAULT ((0)) FOR [IsConfigurableModify]
GO

-- %% [markdown]
-- # [DF_Privilege_IsConfigurableStatus]

-- %%
ALTER TABLE [dbo].[PRIVILEGE] ADD  CONSTRAINT [DF_Privilege_IsConfigurableStatus]  DEFAULT ((0)) FOR [IsConfigurableStatus]
GO

-- %% [markdown]
-- # [DF_Privilege_IsConfigurableExecution]

-- %%
ALTER TABLE [dbo].[PRIVILEGE] ADD  CONSTRAINT [DF_Privilege_IsConfigurableExecution]  DEFAULT ((0)) FOR [IsConfigurableExecution]
GO

-- %% [markdown]
-- # [DF_Privilege_LastEditAt]

-- %%
ALTER TABLE [dbo].[PRIVILEGE] ADD  CONSTRAINT [DF_Privilege_LastEditAt]  DEFAULT (getdate()) FOR [LastEditAt]
GO

-- %% [markdown]
-- # [DF__Projet__CreatedA__336AA144]

-- %%
ALTER TABLE [dbo].[Projet] ADD  DEFAULT (getdate()) FOR [CreatedAt]
GO

-- %% [markdown]
-- # [DF__Projet__Type__62E4AA3C]

-- %%
ALTER TABLE [dbo].[Projet] ADD  DEFAULT ('Equipe') FOR [Type]
GO

-- %% [markdown]
-- # [DF__Projet__Progress__63D8CE75]

-- %%
ALTER TABLE [dbo].[Projet] ADD  DEFAULT ((0)) FOR [Progress]
GO

-- %% [markdown]
-- # [DF__ROLE_DEFI__isAct__4316F928]

-- %%
ALTER TABLE [dbo].[ROLE_DEFINITION] ADD  DEFAULT ((1)) FOR [isActive]
GO

-- %% [markdown]
-- # [DF__ROLE_DEFI__creat__440B1D61]

-- %%
ALTER TABLE [dbo].[ROLE_DEFINITION] ADD  DEFAULT (getdate()) FOR [createdAt]
GO

-- %% [markdown]
-- # [DF__ROLE_DEFI__creat__5FB337D6]

-- %%
ALTER TABLE [dbo].[RoleDefinitionPrivilege] ADD  DEFAULT (getdate()) FOR [createdAt]
GO

-- %% [markdown]
-- # [DF__Task__Status__0D44F85C]

-- %%
ALTER TABLE [dbo].[Task] ADD  DEFAULT ('En attente') FOR [Status]
GO

-- %% [markdown]
-- # [DF__Task__CreatedAt__0E391C95]

-- %%
ALTER TABLE [dbo].[Task] ADD  DEFAULT (getdate()) FOR [CreatedAt]
GO

-- %% [markdown]
-- # [DF__Team__CreatedAt__2EA5EC27]

-- %%
ALTER TABLE [dbo].[Team] ADD  DEFAULT (getdate()) FOR [CreatedAt]
GO

-- %% [markdown]
-- # [DF_User_IsActivate]

-- %%
ALTER TABLE [dbo].[USER] ADD  CONSTRAINT [DF_User_IsActivate]  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF_User_CreatedAt]

-- %%
ALTER TABLE [dbo].[USER] ADD  CONSTRAINT [DF_User_CreatedAt]  DEFAULT (getdate()) FOR [CreatedAt]
GO

-- %% [markdown]
-- # [DF__USER_ACCE__creat__5AEE82B9]

-- %%
ALTER TABLE [dbo].[UserAccess] ADD  DEFAULT (getdate()) FOR [CreatedAt]
GO

-- %% [markdown]
-- # [DF__USER_ACCE__creat__5629CD9C]

-- %%
ALTER TABLE [dbo].[UserAccessCompetency] ADD  DEFAULT (getdate()) FOR [CreatedAt]
GO

-- %% [markdown]
-- # [FK_AccessCompetency_Parent]

-- %%
ALTER TABLE [dbo].[ACCESS_COMPETENCY]  WITH CHECK ADD  CONSTRAINT [FK_AccessCompetency_Parent] FOREIGN KEY([parentId])
REFERENCES [dbo].[ACCESS_COMPETENCY] ([id])
GO
ALTER TABLE [dbo].[ACCESS_COMPETENCY] CHECK CONSTRAINT [FK_AccessCompetency_Parent]
GO

-- %% [markdown]
-- # [FK_AuditLogs_User]

-- %%
ALTER TABLE [dbo].[AUDIT_LOGS]  WITH CHECK ADD  CONSTRAINT [FK_AuditLogs_User] FOREIGN KEY([userId])
REFERENCES [dbo].[USER] ([ID])
GO
ALTER TABLE [dbo].[AUDIT_LOGS] CHECK CONSTRAINT [FK_AuditLogs_User]
GO

-- %% [markdown]
-- # [FK__Contract__UserId__17C286CF]

-- %%
ALTER TABLE [dbo].[Contract]  WITH CHECK ADD FOREIGN KEY([UserId])
REFERENCES [dbo].[USER] ([ID])
GO

-- %% [markdown]
-- # [FK_Messages_RecipientTeam]

-- %%
ALTER TABLE [dbo].[Messages]  WITH CHECK ADD  CONSTRAINT [FK_Messages_RecipientTeam] FOREIGN KEY([RecipientTeamId])
REFERENCES [dbo].[Team] ([Id])
GO
ALTER TABLE [dbo].[Messages] CHECK CONSTRAINT [FK_Messages_RecipientTeam]
GO

-- %% [markdown]
-- # [FK_Messages_RecipientUser]

-- %%
ALTER TABLE [dbo].[Messages]  WITH CHECK ADD  CONSTRAINT [FK_Messages_RecipientUser] FOREIGN KEY([RecipientUserId])
REFERENCES [dbo].[USER] ([ID])
GO
ALTER TABLE [dbo].[Messages] CHECK CONSTRAINT [FK_Messages_RecipientUser]
GO

-- %% [markdown]
-- # [FK_Messages_Sender]

-- %%
ALTER TABLE [dbo].[Messages]  WITH CHECK ADD  CONSTRAINT [FK_Messages_Sender] FOREIGN KEY([SenderId])
REFERENCES [dbo].[USER] ([ID])
GO
ALTER TABLE [dbo].[Messages] CHECK CONSTRAINT [FK_Messages_Sender]
GO

-- %% [markdown]
-- # [FK_NOTIFICATION_USER]

-- %%
ALTER TABLE [dbo].[NOTIFICATIONS]  WITH CHECK ADD  CONSTRAINT [FK_NOTIFICATION_USER] FOREIGN KEY([UserId])
REFERENCES [dbo].[USER] ([ID])
GO
ALTER TABLE [dbo].[NOTIFICATIONS] CHECK CONSTRAINT [FK_NOTIFICATION_USER]
GO

-- %% [markdown]
-- # [FK_PasswordHistory_User]

-- %%
ALTER TABLE [dbo].[PASSWORD_HISTORY]  WITH CHECK ADD  CONSTRAINT [FK_PasswordHistory_User] FOREIGN KEY([UserId])
REFERENCES [dbo].[USER] ([ID])
GO
ALTER TABLE [dbo].[PASSWORD_HISTORY] CHECK CONSTRAINT [FK_PasswordHistory_User]
GO

-- %% [markdown]
-- # [FK_Payslips_User]

-- %%
ALTER TABLE [dbo].[Payslips]  WITH CHECK ADD  CONSTRAINT [FK_Payslips_User] FOREIGN KEY([UserId])
REFERENCES [dbo].[USER] ([ID])
GO
ALTER TABLE [dbo].[Payslips] CHECK CONSTRAINT [FK_Payslips_User]
GO

-- %% [markdown]
-- # [FK_Projet_Manager]

-- %%
ALTER TABLE [dbo].[Projet]  WITH CHECK ADD  CONSTRAINT [FK_Projet_Manager] FOREIGN KEY([ManagerId])
REFERENCES [dbo].[USER] ([ID])
GO
ALTER TABLE [dbo].[Projet] CHECK CONSTRAINT [FK_Projet_Manager]
GO

-- %% [markdown]
-- # [FK_Projet_Team]

-- %%
ALTER TABLE [dbo].[Projet]  WITH CHECK ADD  CONSTRAINT [FK_Projet_Team] FOREIGN KEY([TeamId])
REFERENCES [dbo].[Team] ([Id])
GO
ALTER TABLE [dbo].[Projet] CHECK CONSTRAINT [FK_Projet_Team]
GO

-- %% [markdown]
-- # [FK_RoleDefinition_Parent]

-- %%
ALTER TABLE [dbo].[ROLE_DEFINITION]  WITH CHECK ADD  CONSTRAINT [FK_RoleDefinition_Parent] FOREIGN KEY([parentRoleId])
REFERENCES [dbo].[ROLE_DEFINITION] ([id])
GO
ALTER TABLE [dbo].[ROLE_DEFINITION] CHECK CONSTRAINT [FK_RoleDefinition_Parent]
GO

-- %% [markdown]
-- # [FK_RoleDefinitionPrivilege_Privilege]

-- %%
ALTER TABLE [dbo].[RoleDefinitionPrivilege]  WITH CHECK ADD  CONSTRAINT [FK_RoleDefinitionPrivilege_Privilege] FOREIGN KEY([PrivilegeId])
REFERENCES [dbo].[PRIVILEGE] ([ID])
GO
ALTER TABLE [dbo].[RoleDefinitionPrivilege] CHECK CONSTRAINT [FK_RoleDefinitionPrivilege_Privilege]
GO

-- %% [markdown]
-- # [FK_RoleDefinitionPrivilege_RoleDefinition]

-- %%
ALTER TABLE [dbo].[RoleDefinitionPrivilege]  WITH CHECK ADD  CONSTRAINT [FK_RoleDefinitionPrivilege_RoleDefinition] FOREIGN KEY([roleDefinitionId])
REFERENCES [dbo].[ROLE_DEFINITION] ([id])
GO
ALTER TABLE [dbo].[RoleDefinitionPrivilege] CHECK CONSTRAINT [FK_RoleDefinitionPrivilege_RoleDefinition]
GO

-- %% [markdown]
-- # [FK__Task__AssignedTo__0F2D40CE]

-- %%
ALTER TABLE [dbo].[Task]  WITH CHECK ADD FOREIGN KEY([AssignedToUserId])
REFERENCES [dbo].[USER] ([ID])
GO

-- %% [markdown]
-- # [FK__Task__CreatedByU__10216507]

-- %%
ALTER TABLE [dbo].[Task]  WITH CHECK ADD FOREIGN KEY([CreatedByUserId])
REFERENCES [dbo].[USER] ([ID])
GO

-- %% [markdown]
-- # [FK_User_Team]

-- %%
ALTER TABLE [dbo].[USER]  WITH CHECK ADD  CONSTRAINT [FK_User_Team] FOREIGN KEY([TeamId])
REFERENCES [dbo].[Team] ([Id])
GO
ALTER TABLE [dbo].[USER] CHECK CONSTRAINT [FK_User_Team]
GO

-- %% [markdown]
-- # [FK_User_Role_User]

-- %%
ALTER TABLE [dbo].[USER_ROLE]  WITH NOCHECK ADD  CONSTRAINT [FK_User_Role_User] FOREIGN KEY([UserID])
REFERENCES [dbo].[USER] ([ID])
GO
ALTER TABLE [dbo].[USER_ROLE] CHECK CONSTRAINT [FK_User_Role_User]
GO

-- %% [markdown]
-- # [FK_UserAccess_Access]

-- %%
ALTER TABLE [dbo].[UserAccess]  WITH CHECK ADD  CONSTRAINT [FK_UserAccess_Access] FOREIGN KEY([AccessId])
REFERENCES [dbo].[ACCESS] ([id])
GO
ALTER TABLE [dbo].[UserAccess] CHECK CONSTRAINT [FK_UserAccess_Access]
GO

-- %% [markdown]
-- # [FK_UserAccess_User]

-- %%
ALTER TABLE [dbo].[UserAccess]  WITH CHECK ADD  CONSTRAINT [FK_UserAccess_User] FOREIGN KEY([UserId])
REFERENCES [dbo].[USER] ([ID])
GO
ALTER TABLE [dbo].[UserAccess] CHECK CONSTRAINT [FK_UserAccess_User]
GO

-- %% [markdown]
-- # [FK_UserAccessCompetency_AccessCompetency]

-- %%
ALTER TABLE [dbo].[UserAccessCompetency]  WITH CHECK ADD  CONSTRAINT [FK_UserAccessCompetency_AccessCompetency] FOREIGN KEY([AccessCompetencyId])
REFERENCES [dbo].[ACCESS_COMPETENCY] ([id])
GO
ALTER TABLE [dbo].[UserAccessCompetency] CHECK CONSTRAINT [FK_UserAccessCompetency_AccessCompetency]
GO

-- %% [markdown]
-- # [FK_UserAccessCompetency_User]

-- %%
ALTER TABLE [dbo].[UserAccessCompetency]  WITH CHECK ADD  CONSTRAINT [FK_UserAccessCompetency_User] FOREIGN KEY([UserId])
REFERENCES [dbo].[USER] ([ID])
GO
ALTER TABLE [dbo].[UserAccessCompetency] CHECK CONSTRAINT [FK_UserAccessCompetency_User]
GO

-- %% [markdown]
-- # [CK__Payslips__Bonus__5772F790]

-- %%
ALTER TABLE [dbo].[Payslips]  WITH CHECK ADD CHECK  (([Bonus]>=(0)))
GO

-- %% [markdown]
-- # [CK__Payslips__Deduct__558AAF1E]

-- %%
ALTER TABLE [dbo].[Payslips]  WITH CHECK ADD CHECK  (([Deductions]>=(0)))
GO

-- %% [markdown]
-- # [CK__Payslips__GrossS__52AE4273]

-- %%
ALTER TABLE [dbo].[Payslips]  WITH CHECK ADD CHECK  (([GrossSalary]>=(0)))
GO

-- %% [markdown]
-- # [CK__Payslips__Month__50C5FA01]

-- %%
ALTER TABLE [dbo].[Payslips]  WITH CHECK ADD CHECK  (([Month]>=(1) AND [Month]<=(12)))
GO

-- %% [markdown]
-- # [CK__Payslips__NetSal__53A266AC]

-- %%
ALTER TABLE [dbo].[Payslips]  WITH CHECK ADD CHECK  (([NetSalary]>=(0)))
GO

-- %% [markdown]
-- # [CK__Payslips__Year__51BA1E3A]

-- %%
ALTER TABLE [dbo].[Payslips]  WITH CHECK ADD CHECK  (([Year]>=(2020) AND [Year]<=(2050)))
GO

-- %% [markdown]
-- # [CK__Projet__Progress__64CCF2AE]

-- %%
ALTER TABLE [dbo].[Projet]  WITH CHECK ADD CHECK  (([Progress]>=(0) AND [Progress]<=(100)))
GO

-- %% [markdown]
-- # [CK_User_Email_Format]

-- %%
ALTER TABLE [dbo].[USER]  WITH NOCHECK ADD  CONSTRAINT [CK_User_Email_Format] CHECK  (([Email] IS NULL OR [Email] like '%_@_%._%'))
GO
ALTER TABLE [dbo].[USER] CHECK CONSTRAINT [CK_User_Email_Format]
GO

-- %% [markdown]
-- # [CK_User_Phone_Format]

-- %%
ALTER TABLE [dbo].[USER]  WITH NOCHECK ADD  CONSTRAINT [CK_User_Phone_Format] CHECK  (([Phone] IS NULL OR NOT [Phone] like '%[^0-9+() -]%'))
GO
ALTER TABLE [dbo].[USER] CHECK CONSTRAINT [CK_User_Phone_Format]
GO
